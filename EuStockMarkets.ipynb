# %%
help(EuStockMarkets)

# %%
str(EuStockMarkets)
# Out:
#  Time-Series [1:1860, 1:4] from 1991 to 1999: 1629 1614 1607 1621 1618 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : NULL
#   ..$ : chr [1:4] "DAX" "SMI" "CAC" "FTSE"

# %%
CAC<-EuStockMarkets[,3]
plot(CAC)
# Out:
# plot without title

# %%
Dec<- decompose(CAC, type="additive")
plot(Dec)
# Out:
# plot without title

# %%
mt<- Dec$trend
plot(CAC)
lines(mt, col="green")
# Out:
# plot without title

# %%
st<- Dec$seasonal

# %%
for(i in 1:1000){if (st[1]==st[i]) print(i)}
# Out:
# [1] 1
# [1] 261
# [1] 521
# [1] 781

# %%
ruido <- Dec$random

# %%
mean(ruido, na.rm=TRUE)
# Out:
# [1] -13.79223

# %%
hist(ruido)
# Out:
# Plot with title “Histogram of ruido”

# %%
acf(ruido, lag.max=100, na.action=na.pass)
# Out:
# Plot with title “Series  ruido”

# %%
help(Box.test)

# %%
Box.test(ruido, lag=50, type="Ljung-Box")
# Out:
# 	Box-Ljung test
#
# data:  ruido
# X-squared = 23951, df = 50, p-value < 2.2e-16

# %%
Concluir juliogalindo@lasallistas.org.mx
